# %% [markdown]
# # Make a single vertical line

# %% [markdown]
# ##  Using axvline()

# %%
# importing the modules
import matplotlib.pyplot as plt
import numpy as np
 
# specifying the plot size
plt.figure(figsize = (10, 5))
 
# only one line may be specified; full height
plt.axvline(x = 7, color = 'b', label = 'axvline - full height')
 
# rendering plot
plt.show()

# %% [markdown]
# ##  Method #2: Using vlines()

# %%
# importing necessary libraries
import matplotlib.pyplot as plt
import numpy as np
 
# defining an array
xs = [1, 100]
 
# defining plot size
plt.figure(figsize = (10, 7))
 
# single line
plt.vlines(x = 37, ymin = 0, ymax = max(xs),
           colors = 'purple',
           label = 'vline_multiple - full height')
 
plt.show()

# %% [markdown]
# ## Method #3: Using plot()

# %%
# importing library
import matplotlib.pyplot as plt
 
# defining plot size
plt.figure(figsize = (10, 5))
 
# specifying plot coordinates
plt.plot((0, 0), (0, 1), scaley = False)
 
# setting scaley = True will make the line fit
# within the frame, i.e It will appear as a finite line
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot((0, 0), (0, 1), scaley=False, color='red')  # 색상을 빨간색으로 지정
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot((0, 0), (0, 1), scaley=False, color='red')  # 색상을 빨간색으로 지정
plt.plot((0.5, 0), (0.5, 1), scaley=False, color='blue')  # 색상을 파란색으로 지정

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot((0, 0), (0, 1), scaley=False, color='red')  # 첫 번째 수직 선 (x=0)
plt.plot((1, 1), (0, 1), scaley=False, color='blue')  # 두 번째 수직 선 (x=1)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot((0, 0), (0, 1), scaley=False, color='red')  # 첫 번째 수직 선 (x=0)
plt.plot((0.1, 0.1), (0, 1), scaley=False, color='blue')  # 두 번째 수직 선 (x=1)
plt.plot((0.2, 0.2), (0, 1), scaley=False, color='green')  # 두 번째 수직 선 (x=1)
plt.plot((0.3, 0.3), (0, 1), scaley=False, color='green')  # 두 번째 수직 선 (x=1)
plt.plot((0.4, 0.4), (0, 1), scaley=False, color='green')  # 두 번째 수직 선 (x=1)
plt.plot((0.5, 0.5), (0, 1), scaley=False, color='green')  # 두 번째 수직 선 (x=1)
plt.plot((0.6, 0.6), (0, 1), scaley=False, color='green')  # 두 번째 수직 선 (x=1)
plt.plot((0.7, 0.7), (0, 1), scaley=False, color='green')  # 두 번째 수직 선 (x=1)

plt.show()

# %% [markdown]
# 파이썬의 Matplotlib 라이브러리를 사용하여 10개의 구분 잘되는 색을 추천해 드릴 수 있습니다. 다음은 추천하는 색상 목록입니다:
#
# #1f77b4 (파란색)
# #ff7f0e (주황색)
# #2ca02c (녹색)
# #d62728 (빨간색)
# #9467bd (보라색)
# #8c564b (갈색)
# #e377c2 (분홍색)
# #7f7f7f (회색)
# #bcbd22 (옐로우)
# #17becf (청록색)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot((0, 0), (0, 1), scaley=False, color='#1f77b4')  # 첫 번째 수직 선 (x=0)
plt.plot((0.1, 0.1), (0, 1), scaley=False, color='#ff7f0e')  # 두 번째 수직 선 (x=1)
plt.plot((0.2, 0.2), (0, 1), scaley=False, color='#2ca02c')  # 두 번째 수직 선 (x=1)
plt.plot((0.3, 0.3), (0, 1), scaley=False, color='#d62728')  # 두 번째 수직 선 (x=1)
plt.plot((0.4, 0.4), (0, 1), scaley=False, color='#9467bd')  # 두 번째 수직 선 (x=1)
plt.plot((0.5, 0.5), (0, 1), scaley=False, color='#8c564b')  # 두 번째 수직 선 (x=1)
plt.plot((0.6, 0.6), (0, 1), scaley=False, color='#e377c2')  # 두 번째 수직 선 (x=1)
plt.plot((0.7, 0.7), (0, 1), scaley=False, color='#7f7f7f')  # 두 번째 수직 선 (x=1)
plt.plot((0.8, 0.8), (0, 1), scaley=False, color='#bcbd22')  # 두 번째 수직 선 (x=1)
plt.plot((0.9, 0.9), (0, 1), scaley=False, color='#17becf')  # 두 번째 수직 선 (x=1)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot((0, 0), (0, 1), scaley=False, color='#1f77b4')  # 첫 번째 수직 선 (x=0)
plt.plot((1, 1), (0, 1), scaley=False, color='#ff7f0e')  # 두 번째 수직 선 (x=1)
plt.plot((2, 2), (0, 1), scaley=False, color='#2ca02c')  # 두 번째 수직 선 (x=1)
plt.plot((3, 3), (0, 1), scaley=False, color='#d62728')  # 두 번째 수직 선 (x=1)
plt.plot((4, 4), (0, 1), scaley=False, color='#9467bd')  # 두 번째 수직 선 (x=1)
plt.plot((5, 5), (0, 1), scaley=False, color='#8c564b')  # 두 번째 수직 선 (x=1)
plt.plot((6, 6), (0, 1), scaley=False, color='#e377c2')  # 두 번째 수직 선 (x=1)
plt.plot((7, 7), (0, 1), scaley=False, color='#7f7f7f')  # 두 번째 수직 선 (x=1)
plt.plot((8, 8), (0, 1), scaley=False, color='#bcbd22')  # 두 번째 수직 선 (x=1)
plt.plot((9, 9), (0, 1), scaley=False, color='#17becf')  # 두 번째 수직 선 (x=1)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot((0, 0), (0, 1), scaley=False, color='#1f77b4')  # 첫 번째 수직 선 (x=0)
plt.plot((1, 1), (0, 1), scaley=False, color='#ff7f0e')  # 두 번째 수직 선 (x=1)
plt.plot((2, 2), (0, 1), scaley=False, color='#2ca02c')  # 세 번째 수직 선 (x=2)
plt.plot((3, 3), (0, 1), scaley=False, color='#d62728')  # 네 번째 수직 선 (x=3)
plt.plot((4, 4), (0, 1), scaley=False, color='#9467bd')  # 다섯 번째 수직 선 (x=4)
plt.plot((5, 5), (0, 1), scaley=False, color='#8c564b')  # 여섯 번째 수직 선 (x=5)
plt.plot((6, 6), (0, 1), scaley=False, color='#e377c2')  # 일곱 번째 수직 선 (x=6)
plt.plot((7, 7), (0, 1), scaley=False, color='#7f7f7f')  # 여덟 번째 수직 선 (x=7)
plt.plot((8, 8), (0, 1), scaley=False, color='#bcbd22')  # 아홉 번째 수직 선 (x=8)
plt.plot((9, 9), (0, 1), scaley=False, color='#17becf')  # 열 번째 수직 선 (x=9)

plt.xticks([])  # x축 눈금 숨김
plt.yticks([])  # y축 눈금 숨김

plt.show()

# %% [markdown]
# # Plotting Multiple Lines

# %% [markdown]
# ## Method #1: Using axvline()

# %%
# importing the modules
import matplotlib.pyplot as plt
import numpy as np
 
# specifying the plot size
plt.figure(figsize = (10, 5))
 
# only one line may be specified; full height
plt.axvline(x = 7, color = 'b', label = 'axvline - full height')
 
# only one line may be specified; ymin & ymax specified as
# a percentage of y-range
plt.axvline(x = 7.25, ymin = 0.1, ymax = 0.90, color = 'r',
            label = 'axvline - % of full height')
 
# place legend outside
plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper left')
 
# rendering plot
plt.show()

# %% [markdown]
# ##  Method #2: Using vlines()

# %%
# importing necessary libraries
import matplotlib.pyplot as plt
import numpy as np
 
# defining an array
xs = [1, 100]
 
# defining plot size
plt.figure(figsize=(10, 7))
 
# multiple lines all full height
plt.vlines(x=[37, 37.25, 37.5], ymin=0, ymax=max(xs),
           colors='purple',
           label='vline_multiple - full height')
 
# multiple lines with varying ymin and ymax
plt.vlines(x=[38, 38.25, 38.5], ymin=[0, 25, 75], ymax=max(xs),
           colors='teal',
           label='vline_multiple - partial height')
 
# single vline with full ymin and ymax
plt.vlines(x=39, ymin=0, ymax=max(xs), colors='green',
           label='vline_single - full height')
 
# single vline with specific ymin and ymax
plt.vlines(x=39.25, ymin=25, ymax=max(xs), colors='green',
           label='vline_single - partial height')
 
# place legend outside
plt.legend(bbox_to_anchor=(1.0, 1), loc='upper left')
plt.show()

# %% [raw]
# 파이썬의 Matplotlib 라이브러리를 사용하여 10개의 구분 잘되는 색을 추천해 드릴 수 있습니다. 다음은 추천하는 색상 목록입니다:
#
# #1f77b4 (파란색)
# #ff7f0e (주황색)
# #2ca02c (녹색)
# #d62728 (빨간색)
# #9467bd (보라색)
# #8c564b (갈색)
# #e377c2 (분홍색)
# #7f7f7f (회색)
# #bcbd22 (옐로우)
# #17becf (청록색)

# %%
import matplotlib.pyplot as plt

# 데이터 예시
x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 18]
z = [9, 19, 14, 24, 17]

# 색상 목록
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
          '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# 색상을 지정하여 플롯
plt.plot(x, y, color=colors[0])  # 원하는 색상의 인덱스를 선택
plt.plot(x, z, color=colors[1])  # 원하는 색상의 인덱스를 선택
plt.show()
